# %%
from __future__ import division
import numpy as np
import matplotlib.pyplot as pl

# %%
n = 1000000
k = 0
for i in range(n):
    x = np.random.random()
    y = np.random.random()
    x1 = x**2
    y1 = y**2
    x_y = x1 + y1
    dxy = np.sqrt(x_y)
    if dxy <=1:
        k = k+1
print('pi wurde angenähert::',4*k/n)
